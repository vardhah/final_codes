# %%
import pandas as pd 
import numpy as np
from pandas_profiling import ProfileReport
import matplotlib.pyplot as plt
import tensorflow as tf
import sys 
import os
import cv2
from PIL import Image

folder= "DATA_withoutPPT"  #file name

# %%
image = Image.open(image_file)

# %%
# Set forest parameters
i=0
while len(forest) < num_trees:
    #Select random subsets of points uniformly
    #np.random.shuffle(X)
    #print(X.shape)
    trees = rrcf.RCTree(X)
    print("creatred tree:",i)
    forest.append(trees)
    i+=1
avg_codisp = pd.Series(0.0, index=np.arange(n))
index = np.zeros(n)
for tree in forest: 
    codisp = pd.Series({leaf : tree.codisp(leaf)
                       for leaf in tree.leaves})
    avg_codisp[codisp.index] += codisp
    np.add.at(index, codisp.index.values, 1)
avg_codisp /= index

#print(forest)
#print("-------> ",avg_codisp[2080])
#if avg_codisp[2080]>30 :
   # break
plt.plot(avg_codisp)
plt.hlines(25,1,2184,'r')
plt.grid()
plt.show()
print(avg_codisp.max())
print(type(forest))
#with open('anomaly_detector', 'wb') as f:
with open('rcf_model', 'wb') as output:
  dill.dump(forest, output, pickle.HIGHEST_PROTOCOL)
np.savez('training_details.npz',n=n,threshold=avg_codisp.max())

# %%
plt.plot(avg_codisp)
#plt.hlines(25,1,2184,'r')
plt.grid()
plt.show()
print(avg_codisp.max())
ind = np.argpartition(avg_codisp, -20)[-20:]
print(avg_codisp[ind])
# Out:
# 571.3286385887094
# 27058    121.043708
# 29693    121.043876
# 42877    181.082992
# 37417    208.184209
# 37424    127.906959
# 37420    192.441328
# 37421    172.313920
# 37423    148.335761
# 1822     152.273937
# 37415    210.481811
# 37411    493.999564
# 37422    284.995569
# 37413    338.695131
# 37419    212.422682
# 37410    571.328639
# 37418    228.105754
# 37414    223.720676
# 868      351.728415
# 37416    321.956550
# 37412    462.425827
# dtype: float64

# %%
new_testpoint=[5.0, 5.0, 5.0]
import time

start_insert=time.time()
for tree in forest:
     tree.insert_point(new_testpoint,index=44172)
done_insert=time.time()
print("time for execution:",done_insert-start_insert)
point_codisp = 0
for tree in forest: 
    codisp = tree.codisp(44172)
    point_codisp += codisp
point_codisp /= 200
done_codisp_calc=time.time()
print("Time for calculating codisp:",done_codisp_calc-start_insert)
print(point_codisp)
# Out:
# time for execution: 1.5996530055999756
# Time for calculating codisp: 1.6013283729553223
# 5029.396390422899

# %%
for tree in forest:
    tree.forget_point(index=44172)

# %%
for tree in forest:
     duplicates=tree.find_duplicate()
     print(duplicates)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-c35edc4aee96> in <module>
#       1 for tree in forest:
# ----> 2      duplicates=tree.find_duplicate()
#       3      print(duplicates)
#
# TypeError: find_duplicate() missing 1 required positional argument: 'point'

# %%
acc=-8.82  #m/s^2
vel=10.8    #m/s
dist=12.16  #m
velocity=[]
distance=[]
cnt=0
while(vel>0.05):
    dist=dist-(vel*0.05+0.5*acc*(0.05)*0.05)
    vel=vel+acc*0.05
    cnt+=1
    distance.append(dist)
    velocity.append(vel)
print("Dist is:",dist)
print("Cnt is:",cnt)

plt.plot(distance,label="Emergency Brake")

real_dist=X[2158:2184][:,0]
plt.plot(real_dist,label="RL controller")
print(len(real_dist))
plt.grid()
plt.legend(loc="upper right")
plt.show()
# Out:
# Dist is: 5.550624999999999
# Cnt is: 25
# 25

# %%
X[2158:2184][:,1]
# Out:
# array([8.95, 8.64, 8.33, 8.02, 7.71, 7.4 , 7.09, 6.79, 6.48, 6.17, 5.86,
#        5.55, 5.24, 4.93, 4.62, 4.32, 4.01, 3.7 , 3.39, 3.08, 2.77, 2.46,
#        2.15, 1.85, 1.54])

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import colors

threshold = avg_codisp.nlargest(n=10).min()
print(threshold)
fig = plt.figure(figsize=(12,4.5))
ax = fig.add_subplot(121, projection='3d')
sc = ax.scatter(X[:,0], X[:,1], X[:,2],
                c=np.log(avg_codisp.sort_index().values),
                cmap='gnuplot2')
#plt.title('log(CoDisp)')
ax = fig.add_subplot(122, projection='3d')
sc = ax.scatter(X[:,0], X[:,1], X[:,2],
                linewidths=0.1, edgecolors='k',
                c=(avg_codisp >= 35).astype(float),
                cmap='cool')
#plt.title('CoDisp above 99.5th percentile')
# Out:
# 37.83333333333333

# %%
tree1 = rrcf.RCTree()

for i in range(6):
    x = np.random.randn(2)
    tree1.insert_point(x, index=i)

# %%
#tree1 = rrcf.RCTree()
x1 = np.random.randn(2)
print(x1)
tree1.insert_point(x1, index=i)
# Out:
# [1.972233   1.18621487]
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-28-611c8e4182d9> in <module>
#       2 x1 = np.random.randn(2)
#       3 print(x1)
# ----> 4 tree1.insert_point(x1, index=i)
#
# ~\Anaconda3new\lib\site-packages\rrcf\rrcf.py in insert_point(self, point, index, tolerance)
#     434         # Check for existing index in leaves dict
#     435         try:
# --> 436             assert (index not in self.leaves)
#     437         except KeyError:
#     438             raise KeyError("Index already exists in leaves dict.")
#
# AssertionError:
